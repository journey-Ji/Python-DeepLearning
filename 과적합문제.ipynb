# %% [markdown]
# <a href="https://colab.research.google.com/github/journey-Ji/Python-DeepLearning/blob/main/%EA%B3%BC%EC%A0%81%ED%95%A9%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.preprocessing import LabelEncoder

import pandas as pd
import numpy
import tensorflow as tf


#seed
numpy.random.seed(3)
tf.random.set_seed(3)

#데이터 입력
df = pd.read_csv('sonar.csv',header=None)

dataset = df.values
X = dataset[:,0:60].astype(float)
Y_obj = dataset[:,60]

#문자열 변환
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)

#model
model = Sequential()
model.add(Dense(24,input_dim=60,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(5,activation='relu'))
model.add(Dense(3,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

#model compile
model.compile(loss = 'mean_squared_error',
              optimizer = 'adam',
              metrics = ['accuracy'])

#model fit
model.fit(X, Y, epochs=200, batch_size=5)

#print
print("\n Accuracy : %.4f"%(model.evaluate(X,Y)[1]))
# Out:
# Epoch 1/200
# 42/42 [==============================] - 1s 2ms/step - loss: 0.2500 - accuracy: 0.5056
# Epoch 2/200
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2386 - accuracy: 0.5159
# Epoch 3/200
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2230 - accuracy: 0.6013
# Epoch 4/200
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2155 - accuracy: 0.6770
# Epoch 5/200
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2002 - accuracy: 0.7230
# Epoch 6/200
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1873 - accuracy: 0.7640
# Epoch 7/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1676 - accuracy: 0.7770
# Epoch 8/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1439 - accuracy: 0.8246
# Epoch 9/200
# 42/42 [==============================] - 0s 1ms/step - loss: 0.1632 - accuracy: 0.7924
# Epoch 10/200
# ...
